# %% [markdown]
# # 📦 Instalação das Bibliotecas
#
# Para executar corretamente este notebook, certifique-se de que as bibliotecas abaixo estão instaladas no ambiente:
#
# - `pandas` → manipulação de dados
# - `matplotlib` → geração de gráficos
# - `seaborn` → visualizações estatísticas
# - `folium` → criação de mapas interativos
# - `wordcloud` → nuvem de palavras
# - `geopandas` → manipulação de dados geográficos
#
# ### ▶️ Comando de instalação (via pip):
#
# Descomente o `%pip install pandas matplotlib seaborn folium wordcloud geopandas` a seguir para poder fazer a instalação dos pacotes.

# %%
# 📦 Instalação das bibliotecas utilizadas no projeto
# %pip install pandas matplotlib seaborn folium wordcloud geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

# Carregar os dados
url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja1 = pd.read_csv(url1)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# Exibir informações sobre o DataFrame
loja1.info()

# Exibir as 5 primeiras e as 5 últimas linhas do DataFrame
loja1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# ...

# %% [markdown]
# # 1. Análise do faturamento

# %%
import numpy as np

# Calculando o faturamento total por loja
faturamento1 = loja1["Preço"].sum()
faturamento2 = loja2["Preço"].sum()
faturamento3 = loja3["Preço"].sum()
faturamento4 = loja4["Preço"].sum()

# Exibindo os resultados
print("📊 Faturamento total por loja:\n")
print(f"Loja 1: R$ {faturamento1:,.2f}")
print(f"Loja 2: R$ {faturamento2:,.2f}")
print(f"Loja 3: R$ {faturamento3:,.2f}")
print(f"Loja 4: R$ {faturamento4:,.2f}")
# Out:
# 📊 Faturamento total por loja:
#
# Loja 1: R$ 1,534,509.12
# Loja 2: R$ 1,488,459.06
# Loja 3: R$ 1,464,025.03
# Loja 4: R$ 1,384,497.58

# %%
import matplotlib.pyplot as plt

# Dados de exemplo
lojas = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
valores = [faturamento1, faturamento2, faturamento3, faturamento4]
cores = ["blue", "green", "purple", "orange"]

# Plot
plt.figure(figsize=(10, 6))
barras = plt.barh(lojas, valores, color=cores)

plt.title("Faturamento Total por Loja", fontsize=16)
plt.xlabel("Faturamento (R$ milhões)", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.5)

# Adiciona os valores dentro das barras
for barra in barras:
    plt.text(barra.get_width() * 0.98,
             barra.get_y() + barra.get_height() / 2,
             f'R$ {barra.get_width():,.0f}',
             va='center', ha='right', fontsize=11, color='white', weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
import seaborn as sns

# Construindo tabela cruzada: categorias x lojas
categorias = sorted(set(loja1["Categoria do Produto"]) |
                    set(loja2["Categoria do Produto"]) |
                    set(loja3["Categoria do Produto"]) |
                    set(loja4["Categoria do Produto"]))

dados = {
    'Loja 1': loja1['Categoria do Produto'].value_counts(),
    'Loja 2': loja2['Categoria do Produto'].value_counts(),
    'Loja 3': loja3['Categoria do Produto'].value_counts(),
    'Loja 4': loja4['Categoria do Produto'].value_counts(),
}

df_heatmap = pd.DataFrame(dados).fillna(0).reindex(categorias)

plt.figure(figsize=(10, 6))
sns.heatmap(df_heatmap, annot=True, fmt='.0f', cmap="coolwarm",)
plt.title("Quantidade de Vendas por Categoria e Loja", fontsize=14)
plt.ylabel("Categoria")
plt.xlabel("Loja")
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# Calcular a média das avaliações
avaliacoes = {
    "Loja 1": loja1["Avaliação da compra"].mean(),
    "Loja 2": loja2["Avaliação da compra"].mean(),
    "Loja 3": loja3["Avaliação da compra"].mean(),
    "Loja 4": loja4["Avaliação da compra"].mean()
}

# Exibir os valores
print("📈 Média das Avaliações por Loja:\n")
for loja, media in avaliacoes.items():
    print(f"{loja}: {media:.2f}")
# Out:
# 📈 Média das Avaliações por Loja:
#
# Loja 1: 3.98
# Loja 2: 4.04
# Loja 3: 4.05
# Loja 4: 4.00

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

lojas = [loja1, loja2, loja3, loja4]
titulos = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
cores = ["blue", "green", "purple", "orange"]  # Cores definidas para cada loja

# Estilo do seaborn
sns.set(style="whitegrid")

# Criar os subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

for i in range(4):
    notas = lojas[i]["Avaliação da compra"]
    media = notas.mean()

    sns.histplot(notas, bins=5, kde=True, ax=axs[i], color=cores[i], edgecolor='black')
    axs[i].axvline(media, color='darkred', linestyle='--', linewidth=2, label='Média')
    axs[i].text(media + 0.1, axs[i].get_ylim()[1] * 0.9,
                f"µ = {media:.2f}", color='darkgreen', fontsize=10)

    axs[i].set_title(titulos[i])
    axs[i].set_xlim(0, 5)
    axs[i].set_xlabel("Avaliação")
    axs[i].set_ylabel("Frequência")
    axs[i].legend()

# Ajustes finais
fig.suptitle("Distribuição das Avaliações por Loja", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
from wordcloud import WordCloud

lojas = [loja1, loja2, loja3, loja4]
titulos = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
cores = ['Blues', 'Greens', 'Purples', 'Oranges']  # 1 cor diferente por loja

# Criar gráfico 2x2 com as nuvens
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

for i in range(4):
    contagem_produtos = lojas[i]['Produto'].value_counts()
    wordcloud = WordCloud(width=800, height=400,
                          background_color='white',
                          colormap=cores[i],
                          max_words=100).generate_from_frequencies(contagem_produtos)

    axs[i].imshow(wordcloud, interpolation='bilinear')
    axs[i].set_title(titulos[i], fontsize=14)
    axs[i].axis('off')

fig.suptitle("Nuvem de Palavras - 100 Produtos Mais Vendidos por Loja", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Patch

# # Recarregar os arquivos CSV
# loja1 = pd.read_csv("/mnt/data/loja_1.csv")
# loja2 = pd.read_csv("/mnt/data/loja_2.csv")
# loja3 = pd.read_csv("/mnt/data/loja_3.csv")
# loja4 = pd.read_csv("/mnt/data/loja_4.csv")

# Listas auxiliares
lojas = [loja1, loja2, loja3, loja4]
titulos = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
colormaps = ["Blues", "Greens", "Purples", "Oranges"]

# Criar subplots 2x2
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle("Top 5 Mais e Menos Vendidos por Loja", fontsize=18)

for i, ax in enumerate(axs.flat):
    df = lojas[i]
    titulo = titulos[i]
    cmap_name = colormaps[i]

    contagem = df["Produto"].value_counts()

    # Top e Bottom 5 em ordem decrescente
    top5 = contagem.head(5)
    bottom5 = contagem.tail(5).sort_values(ascending=False)
    juntos = pd.concat([top5, bottom5])

    # Normalizar para intensidade da cor
    norm = mcolors.Normalize(vmin=juntos.min(), vmax=juntos.max())
    cmap = plt.get_cmap(cmap_name)
    cores = [cmap(norm(v)) for v in juntos.values]

    # Desenhar barras com borda
    bars = ax.barh(juntos.index, juntos.values, color=cores, edgecolor='black')
    ax.set_title(titulo, fontsize=14)
    ax.set_xlabel("Quantidade Vendida")
    ax.invert_yaxis()

    # Linha tracejada separando top5 e bottom5
    ax.axhline(y=4.5, color='gray', linestyle='--', linewidth=1.2)

    # Adicionar legenda
    legenda = [
        Patch(facecolor=cmap(norm(top5.max())), edgecolor='black', label='Top 5 Mais Vendidos'),
        Patch(facecolor=cmap(norm(bottom5.max())), edgecolor='black', label='Top 5 Menos Vendidos')
    ]
    ax.legend(handles=legenda, loc='lower right')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# Cálculo do frete médio
fretes = {
    "Loja 1": loja1["Frete"].mean(),
    "Loja 2": loja2["Frete"].mean(),
    "Loja 3": loja3["Frete"].mean(),
    "Loja 4": loja4["Frete"].mean()
}

# Exibir os resultados
print("🚚 Frete Médio por Loja:\n")
for loja, valor in fretes.items():
    print(f"{loja}: R$ {valor:.2f}")
# Out:
# 🚚 Frete Médio por Loja:
#
# Loja 1: R$ 34.69
# Loja 2: R$ 33.62
# Loja 3: R$ 33.07
# Loja 4: R$ 31.28

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Recarregar os arquivos CSV
# loja1 = pd.read_csv("/mnt/data/loja_1.csv")
# loja2 = pd.read_csv("/mnt/data/loja_2.csv")
# loja3 = pd.read_csv("/mnt/data/loja_3.csv")
# loja4 = pd.read_csv("/mnt/data/loja_4.csv")

# Coletar fretes e definir rótulos
fretes = [loja1["Frete"], loja2["Frete"], loja3["Frete"], loja4["Frete"]]
labels = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
cores = ["blue", "green", "purple", "orange"]

# Criar o boxplot
plt.figure(figsize=(10, 6))
bp = plt.boxplot(fretes, labels=labels, patch_artist=True,
                 medianprops=dict(color='black', linewidth=2),
                 flierprops=dict(markerfacecolor='red', marker='o', markersize=5))

# Aplicar cores às caixas
for patch, cor in zip(bp['boxes'], cores):
    patch.set_facecolor(cor)
    patch.set_edgecolor('black')

# Adicionar marcadores e rótulos de média e mediana
for i, dados in enumerate(fretes):
    media = dados.mean()
    mediana = dados.median()
    pos_x = i + 1

    # Ponto da média
    plt.plot(pos_x, media, marker='X', color='black', markersize=10)

    # Seta com valor da média
    plt.annotate(f"µ = {media:.2f}", xy=(pos_x, media), xytext=(pos_x + 0.3, media + 2),
                 arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=6),
                 fontsize=9, color='black', va='center')

    # Valor da mediana (direita da box)
    plt.text(pos_x + 0.3, mediana, f"Mediana = {mediana:.2f}", fontsize=9, color='black', va='center')

# Ajustes finais
plt.title("Distribuição do Frete por Loja (Boxplot)", fontsize=14)
plt.ylabel("Valor do Frete (R$)")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Extra!  Análise de Desempenho Geográfico

# %%
import geopandas as gpd

# Agrupar por estado e contar vendas
estados_loja1 = loja1["Local da compra"].value_counts()
estados_loja2 = loja2["Local da compra"].value_counts()
estados_loja3 = loja3["Local da compra"].value_counts()
estados_loja4 = loja4["Local da compra"].value_counts()

# Baixar mapa dos estados do Brasil via GeoPandas
br = gpd.read_file("https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/brazil-states.geojson")

# Ajustar nomes dos estados para siglas no DataFrame
br["sigla"] = br["name"].map({
    'Acre': 'AC', 'Alagoas': 'AL', 'Amapá': 'AP', 'Amazonas': 'AM',
    'Bahia': 'BA', 'Ceará': 'CE', 'Distrito Federal': 'DF', 'Espírito Santo': 'ES',
    'Goiás': 'GO', 'Maranhão': 'MA', 'Mato Grosso': 'MT', 'Mato Grosso do Sul': 'MS',
    'Minas Gerais': 'MG', 'Pará': 'PA', 'Paraíba': 'PB', 'Paraná': 'PR',
    'Pernambuco': 'PE', 'Piauí': 'PI', 'Rio de Janeiro': 'RJ', 'Rio Grande do Norte': 'RN',
    'Rio Grande do Sul': 'RS', 'Rondônia': 'RO', 'Roraima': 'RR', 'Santa Catarina': 'SC',
    'São Paulo': 'SP', 'Sergipe': 'SE', 'Tocantins': 'TO'
})

# Adicionar colunas de vendas por estado no GeoDataFrame
for loja_nome, vendas in zip(["Loja 1", "Loja 2", "Loja 3", "Loja 4"],
                              [estados_loja1, estados_loja2, estados_loja3, estados_loja4]):
    br[loja_nome] = br["sigla"].map(vendas).fillna(0)

# Plotar os 4 mapas lado a lado
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
lojas = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
cores = ["Blues", "Greens", "Purples", "Oranges"]

for i, ax in enumerate(axs.flat):
    loja = lojas[i]
    br.plot(column=loja, cmap=cores[i], linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
    ax.set_title(f'Densidade de Vendas - {loja}', fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Carregar arquivos CSV
lojas = [loja1, loja2, loja3, loja4]
titulos = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
cores = ["blue", "green", "purple", "orange"]

# Mapa do Brasil
br = gpd.read_file("https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/brazil-states.geojson")

# Criar gráfico 2x2
fig, axs = plt.subplots(2, 2, figsize=(16, 12))

for i, ax in enumerate(axs.flat):
    df = lojas[i]
    
    # Agrupar por estado
    agrupado = df.groupby("Local da compra").agg({
        "lat": "mean",
        "lon": "mean",
        "Produto": "count"
    }).rename(columns={"Produto": "quantidade"}).reset_index()
    
    # Plotar mapa base
    br.plot(ax=ax, color="whitesmoke", edgecolor="gray")
    
    # Plotar bolinhas proporcionais
    ax.scatter(
        agrupado["lon"],
        agrupado["lat"],
        s=agrupado["quantidade"] * 2,  # ajuste o fator de escala se necessário
        color=cores[i],
        alpha=0.6,
        label='Quantidade de vendas'
    )
    
    ax.set_title(f"Concentração de Vendas - {titulos[i]}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
import folium
from folium.plugins import HeatMap

def criar_mapa_loja(df, nome_loja, cor='blue'):
    mapa = folium.Map(location=[-15.78, -47.93], zoom_start=4, tiles="CartoDB positron")
    
    for _, row in df.iterrows():
        folium.CircleMarker(
            location=[row['lat'], row['lon']],
            radius=3,
            color=cor,
            fill=True,
            fill_opacity=0.6
        ).add_to(mapa)
    
    mapa.save(f"mapa_{nome_loja.lower().replace(' ', '_')}.html")
    return mapa

# Exemplo de uso:
mapa1 = criar_mapa_loja(loja1, "Loja 1", "blue")
mapa2 = criar_mapa_loja(loja2, "Loja 2", "green")
mapa3 = criar_mapa_loja(loja3, "Loja 3", "purple")
mapa4 = criar_mapa_loja(loja4, "Loja 4", "orange")

# %% [markdown]
# Veja o mapa interativo da Loja 1 aqui: [mapa_interativo.html](./mapa_loja_1.html)
# Veja o mapa interativo da Loja 2 aqui: [mapa_interativo.html](./mapa_loja_2.html)
# Veja o mapa interativo da Loja 3 aqui: [mapa_interativo.html](./mapa_loja_3.html)
# Veja o mapa interativo da Loja 4 aqui: [mapa_interativo.html](./mapa_loja_4.html)

# %% [markdown]
# # 🛍️ Relatório Final – Análise das Lojas da Alura Store
#
# ## 📌 Introdução
#
# O objetivo deste relatório é auxiliar o Senhor João na tomada de decisão sobre qual das quatro lojas da rede **Alura Store** deve ser vendida. Para isso, foi realizada uma análise completa com base em diversos indicadores de desempenho, como:
#
# - Faturamento total
# - Volume e diversidade de vendas por categoria
# - Avaliações dos clientes
# - Produtos mais e menos vendidos
# - Custos logísticos (frete)
# - Distribuição geográfica das vendas
#
# As análises foram apoiadas por **gráficos descritivos**, visualizações geográficas e comparativos claros entre as lojas.
#
# ---
#
# ## 📈 Faturamento Total por Loja
#
# ![Faturamento Total](./gráficos/faturamento_total_por_loja.png)
#
# A análise de faturamento mostrou que:
#
# - **Loja 1** teve o maior faturamento, com R$ 1.534.509
# - **Loja 4** teve o menor faturamento, com R$ 1.384.498 ✅
#
# Essa diferença já indica que a **Loja 4 tem um desempenho financeiro inferior**, sendo a única abaixo de R$ 1,4 milhão.
#
# ---
#
# ## 📦 Categorias de Produtos Mais Vendidas
#
# ![Vendas por Categoria](./gráficos/quantidade_de_vendas_por_categoria_e_por_loja.png)
#
# **Todas** as quatro lojas apresentaram as categorias móveis, eletrônicos e brinquedos como top 3 categorias de vendas.
# Contudo, a **Loja 4** apresentou menor desempenho em categorias estratégicas**, como eletrodomésticos e instrumentos musicais.
#
# - Loja 1 teve o pior desempenho nas categorias livros (173 vendas) e utilidades domésticas (171 vendas)
# - Loja 2 foi a que menos vendeu nas categorias móveis (442 vendas) e eletrônicos (422 vendas)
# - Loja 3 teve destaque na categoria móveis (499 vendas)
# - Loja 4 vendeu menos nas categorias eletrodomésticos (254 vendas) e instrumentos musicais (170 vendas)
#
# ---
#
# ## 📊 Produtos Mais e Menos Vendidos
#
# ![Top e Bottom 5 por Loja](./gráficos/top5_mais_e_menos_vendidos_por_loja.png)
#
# - A **Loja 1** possui um mix de produtos com líderes claros de venda, como *TV Led UHD 4K* e *Micro-ondas*
# - A **Loja 4** apresenta **mais dispersão** e menos consistência, com vendas muito divididas entre diversos produtos
#
# Isso demonstra **falta de foco comercial** e menor aderência dos produtos aos clientes.
#
# ---
#
# ## ☁️ Nuvem de Palavras – Produtos Mais Vendidos
#
# ![Nuvem de Palavras](./gráficos/nuvem_de_palavras-100_produtos_mais_vendidos_por_loja.png)
#
# - Loja 1: produtos de alto valor e desejo (ex: *Micro-ondas*, *TV UHD*, *Cômoda*)
# - Loja 4: produtos genéricos e pulverizados (ex: *Cama box*, *Faqueiro*, *Dashboard Power BI*)
#
# As nuvens confirmam a **maior especialização** das outras lojas comparada à Loja 4.
#
# ---
#
# ## ⭐ Distribuição das Avaliações por Loja
#
# ![Avaliações](./gráficos/distribuição_das_avaliações_por_loja.png)
#
# As notas de avaliação média foram:
#
# - Loja 3: **4.05**
# - Loja 2: **4.04**
# - Loja 4: **4.00**
# - Loja 1: **3.98**
#
# Apesar de **a Loja 4 não ter a pior média**, sua distribuição de notas mostra menor frequência de avaliações altas em relação às demais.
#
# ---
#
# ## 🚚 Frete Médio por Loja
#
# ![Boxplot de Frete](./gráficos/distribuição_do_frete_por_loja.png)
#
# Analisando os custos logísticos:
#
# - Loja 1: **média = R$ 34,69 / mediana = R$ 16,50**
# - Loja 4: **média = R$ 31,28 / mediana = R$ 14,61**
#
# Embora a **Loja 4 tenha o menor custo médio de frete**, esse aspecto isolado não compensa os fracos resultados em faturamento e vendas.
#
# ---
#
# ## 🗺️ Concentração Geográfica das Vendas
#
# ![Mapa Geográfico](./gráficos/concentração_geográfica_de_vendas_das_lojas.png)
#
# - As lojas 1, 2, 3 e 4 possuem **concentração de vendas forte no Sudeste e Sul**
# - Os 3 **estados com maior concentração de vendas são São Paulo, Rio de Janeiro e Minas Gerais**
# - Loja 4 tem **distribuição dispersa**, sem lojas em alguns estados como Acre e Roraima, o que dificulta ações logísticas e de marketing
#
# ---
#
# ## ✅ Conclusão e Recomendação
#
# Com base nas análises apresentadas, a **Loja 4** demonstra o pior desempenho geral:
#
# - 📉 Menor faturamento total
# - 💸 Menor eficiência nas categorias e produtos mais vendidos
# - 🤔 Menor clareza de posicionamento comercial
# - 📦 Produtos com vendas dispersas e fracos destaques
# - 🧭 Distribuição geográfica dispensa, sem lojas em alguns estados, o que dificulta ações logísticas
#
# Dessa forma, recomendamos que **o Senhor João venda a Loja 4**, redirecionando seus esforços para as lojas com **maior potencial de crescimento e fidelização de clientes**.
#
# ---
